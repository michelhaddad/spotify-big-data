# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date, timedelta

# %%
# Read Data
top_200_2019 = pd.read_csv('../data/streams_2019-01-01__2020-01-01.csv')
song_features_2019 = pd.read_csv('../data/song_features_2019-01-01__2020-01-01.csv')
top_200_2019 = top_200_2019.merge(song_features_2019, on=['track_id'])
top_200_2019.head(50)
# Out:
#     Position                                     Track Name         Artist  \
# 0          1                                  thank u, next  Ariana Grande
# 1          2                                  thank u, next  Ariana Grande
# 2          2                                  thank u, next  Ariana Grande
# 3          2                                  thank u, next  Ariana Grande
# 4          2                                  thank u, next  Ariana Grande
# 5          2                                  thank u, next  Ariana Grande
# 6          3                                  thank u, next  Ariana Grande
# 7          3                                  thank u, next  Ariana Grande
# 8          3                                  thank u, next  Ariana Grande
# 9          3                                  thank u, next  Ariana Grande
# 10         3                                  thank u, next  Ariana Grande
# 11         3                                  thank u, next  Ariana Grande
# 12         2                                  thank u, next  Ariana Grande
# 13         3                                  thank u, next  Ariana Grande
# 14         3                                  thank u, next  Ariana Grande
# 15         4                                  thank u, next  Ariana Grande
# 16         4                                  thank u, next  Ariana Grande
# 17         4                                  thank u, next  Ariana Grande
# 18         4                                  thank u, next  Ariana Grande
# 19         4                                  thank u, next  Ariana Grande
# 20         4                                  thank u, next  Ariana Grande
# 21         5                                  thank u, next  Ariana Grande
# 22         5                                  thank u, next  Ariana Grande
# 23         6                                  thank u, next  Ariana Grande
# 24         6                                  thank u, next  Ariana Grande
# 25         6                                  thank u, next  Ariana Grande
# 26         6                                  thank u, next  Ariana Grande
# 27         6                                  thank u, next  Ariana Grande
# 28         6                                  thank u, next  Ariana Grande
# 29         6                                  thank u, next  Ariana Grande
# 30         8                                  thank u, next  Ariana Grande
# 31         8                                  thank u, next  Ariana Grande
# 32         8                                  thank u, next  Ariana Grande
# 33         9                                  thank u, next  Ariana Grande
# 34         8                                  thank u, next  Ariana Grande
# 35         8                                  thank u, next  Ariana Grande
# 36         9                                  thank u, next  Ariana Grande
# 37         9                                  thank u, next  Ariana Grande
# 38         2  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 39         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 40         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 41         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 42         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 43         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 44         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 45         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 46         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 47         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 48         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 49         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
#
#     Streams                                                URL        date  \
# 0   3978028  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-01
# 1   4275439  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-02
# 2   4320260  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-03
# 3   4385311  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-04
# 4   4194463  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-05
# 5   3872308  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-06
# 6   4266029  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-07
# 7   4282739  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-08
# 8   4270395  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-09
# 9   4224520  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-10
# 10  4221343  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-11
# 11  4037285  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-12
# 12  3614508  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-13
# 13  3889128  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-14
# 14  3906626  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-15
# 15  3944461  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-16
# 16  3866610  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-17
# 17  4305111  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-18
# 18  4109510  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-19
# 19  3636447  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-20
# 20  3827937  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-21
# 21  3813433  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-22
# 22  3857437  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-23
# 23  3819475  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-24
# 24  3789417  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-25
# 25  3580510  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-26
# 26  3170880  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-27
# 27  3370494  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-28
# 28  3384156  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-29
# 29  3347067  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-30
# 30  3346474  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-31
# 31  3429083  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-02-01
# 32  3291574  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-02-02
# 33  2975357  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-02-03
# 34  3032583  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-02-04
# 35  3098156  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019
# 7          0.280               0.0         0.724    1       207333    -5.642
# 8          0.280               0.0         0.724    1       207333    -5.642
# 9          0.280               0.0         0.724    1       207333    -5.642
# 10         0.280               0.0         0.724    1       207333    -5.642
# 11         0.280               0.0         0.724    1       207333    -5.642
# 12         0.280               0.0         0.724    1       207333    -5.642
# 13         0.280               0.0         0.724    1       207333    -5.642
# 14         0.280               0.0         0.724    1       207333    -5.642
# 15         0.280               0.0         0.724    1       207333    -5.642
# 16         0.280               0.0         0.724    1       207333    -5.642
# 17         0.280               0.0         0.724    1       207333    -5.642
# 18         0.280               0.0         0.724    1       207333    -5.642
# 19         0.280               0.0         0.724    1       207333    -5.642
# 20         0.280               0.0         0.724    1       207333    -5.642
# 21         0.280               0.0         0.724    1       207333    -5.642
# 22         0.280               0.0         0.724    1       207333    -5.642
# 23         0.280               0.0         0.724    1       207333    -5.642
# 24         0.280               0.0         0.724    1       207333    -5.642
# 25         0.280               0.0         0.724    1       207333    -5.642
# 26         0.280               0.0         0.724    1       207333    -5.642
# 27         0.280               0.0         0.724    1       207333    -5.642
# 28         0.280               0.0         0.724    1       207333    -5.642
# 29         0.280               0.0         0.724    1       207333    -5.642
# 30         0.280               0.0         0.724    1       207333    -5.642
# 31         0.280               0.0         0.724    1       207333    -5.642
# 32         0.280               0.0         0.724    1       207333    -5.642
# 33         0.280               0.0         0.724    1       207333    -5.642
# 34         0.280               0.0         0.724    1       207333    -5.642
# 35         0.280               0.0         0.724    1       207333    -5.642
# 36         0.280               0.0         0.724    1       207333    -5.642
# 37         0.280               0.0         0.724    1       207333    -5.642
# 38         0.556               0.0         0.760    2       158040    -5.574
# 39         0.556               0.0         0.760    2       158040    -5.574
# 40         0.556               0.0         0.760    2       158040    -5.574
# 41         0.556               0.0         0.760    2       158040    -5.574
# 42         0.556               0.0         0.760    2       158040    -5.574
# 43         0.556               0.0         0.760    2       158040    -5.574
# 44         0.556               0.0         0.760    2       158040    -5.574
# 45         0.556               0.0         0.760    2       158040    -5.574
# 46         0.556               0.0         0.760    2       158040    -5.574
# 47         0.556               0.0         0.760    2       158040    -5.574
# 48         0.556               0.0         0.760    2       158040    -5.574
# 49         0.556               0.0         0.760    2       158040    -5.574
#
#     mode  valence
# 0      1    0.435
# 1      1    0.435
# 2      1    0.435
# 3      1    0.435
# 4      1    0.435
# 5      1    0.435
# 6      1    0.435
# 7      1    0.435
# 8      1    0.435
# 9      1    0.435
# 10     1    0.435
# 11     1    0.435
# 12     1    0.435
# 13     1    0.435
# 14     1    0.435
# 15     1    0.435
# 16     1    0.435
# 17     1    0.435
# 18     1    0.435
# 19     1    0.435
# 20     1    0.435
# 21     1    0.435
# 22     1    0.435
# 23     1    0.435
# 24     1    0.435
# 25     1    0.435
# 26     1    0.435
# 27     1    0.435
# 28     1    0.435
# 29     1    0.435
# 30     1    0.435
# 31     1    0.435
# 32     1    0.435
# 33     1    0.435
# 34     1    0.435
# 35     1    0.435
# 36     1    0.435
# 37     1    0.435
# 38     1    0.913
# 39     1    0.913
# 40     1    0.913
# 41     1    0.913
# 42     1    0.913
# 43     1    0.913
# 44     1    0.913
# 45     1    0.913
# 46     1    0.913
# 47     1    0.913
# 48     1    0.913
# 49     1    0.913

# %%
# Danceability parameter
dates = [date for date in top_200_2019['date'].unique()]
danceability_avg = []

for date in dates:
    daily_chart = top_200_2019[top_200_2019['date'] == date]
    danceability_avg.append(daily_chart.nlargest(5, ['Position'])['danceability'].mean())
    
weeks_average = []
count = 0
i = 0
currSum = 0
while i < len(dates):
    currSum += danceability_avg[i]
    count += 1
    if count == 7:
        weeks_average.append(currSum / count)
        currSum = 0
        count = 0
    i += 1

def allsundays(year):
   d = datetime.date(year, 1, 1)                    
   d += timedelta(days = 6 - d.weekday()) 
   while d.year == year:
      yield d
      d += timedelta(days = 7)

days = []
for i in allsundays(2019):
    days.append(i.strftime('%m-%d'))
plt.plot([i for i in days], weeks_average)
plt.xticks([i for i in days],  rotation='vertical')
plt.grid(color='b', linestyle='-', linewidth=0.2, axis='x')
plt.rcParams["figure.figsize"] = (30,15)
plt.suptitle('Danceability Weekly Average', fontsize=25)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Danceability Weekly Average', fontsize=20)
plt.show()

# %%
# Energy parameter

dates = [date for date in top_200_2019['date'].unique()]
energy_avg = []

for date in dates:
    daily_chart = top_200_2019[top_200_2019['date'] == date]
    energy_avg.append(daily_chart.nlargest(5, ['Position'])['energy'].mean())
    
weeks_average = []
count = 0
i = 0
currSum = 0
while i < len(dates):
    currSum += energy_avg[i]
    count += 1
    if count == 7:
        weeks_average.append(currSum / count)
        currSum = 0
        count = 0
    i += 1

def allsundays(year):
   d = datetime.date(year, 1, 1)        
   d += timedelta(days = 6 - d.weekday())
   while d.year == year:
      yield d
      d += timedelta(days = 7)

days = []
for i in allsundays(2019):
    days.append(i.strftime('%m-%d'))
plt.plot([i for i in days], weeks_average)
plt.xticks([i for i in days],  rotation='vertical')
plt.grid(color='b', linestyle='-', linewidth=0.2, axis='x')
plt.rcParams["figure.figsize"] = (30,15)
plt.suptitle('Energy Weekly Average', fontsize=25)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Energy Weekly Average', fontsize=20)
plt.show()

# %%
# Valence parameter
dates = [date for date in top_200_2019['date'].unique()]
valence_avg = []

for date in dates:
    daily_chart = top_200_2019[top_200_2019['date'] == date]
    valence_avg.append(daily_chart.nlargest(5, ['Position'])['valence'].mean())
    
weeks_average = []
count = 0
i = 0
currSum = 0
while i < len(dates):
    currSum += valence_avg[i]
    count += 1
    if count == 7:
        weeks_average.append(currSum / count)
        currSum = 0
        count = 0
    i += 1

def allsundays(year):
   d = datetime.date(year, 1, 1)                
   d += timedelta(days = 6 - d.weekday())  
   while d.year == year:
      yield d
      d += timedelta(days = 7)

days = []
for i in allsundays(2019):
    days.append(i.strftime('%m-%d'))
plt.plot([i for i in days], weeks_average)
plt.xticks([i for i in days],  rotation='vertical')
plt.grid(color='b', linestyle='-', linewidth=0.2, axis='x')
plt.rcParams["figure.figsize"] = (30,15)
plt.suptitle('Valence Weekly Average', fontsize=25)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Valence Weekly Average', fontsize=20)
plt.show()
